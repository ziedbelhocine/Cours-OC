# %%
import pandas as pd
import numpy as np

data = pd.read_csv('prets.csv')

# %%
display(data)
# Out:
#      identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0              0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1              1      PARIS  75009  5310.0         240.00     64  automobile
# 2              1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3              2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4              3  MARSEILLE  13010  1684.0         586.03    180  immobilier
# ..           ...        ...    ...     ...            ...    ...         ...
# 239          224      PARIS  75008  5118.0        1248.79    300  immobilier
# 240          224      PARIS  75008  5118.0         238.20     25  automobile
# 241          225   BORDEAUX  33100  2356.0         876.43    180  immobilier
# 242          226      PARIS  75002  5098.0        2910.96    240  immobilier
# 243          227      PARIS  75015  2348.0         434.38    300  immobilier
#
#       taux
# 0    1.168
# 1    3.701
# ...

# %%
data.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#     taux
# 0  1.168
# 1  3.701
# 2  1.173
# 3  0.972
# 4  1.014

# %%
data.loc[data['type'] == 'automobile'].sort_values('revenu', ascending=False)
# Out:
#      identifiant      ville     CP  revenu  remboursement  duree        type  \
# 100           95      PARIS  75016  6069.0          341.4     24  automobile
# 1              1      PARIS  75009  5310.0          240.0     64  automobile
# 240          224      PARIS  75008  5118.0          238.2     25  automobile
# 106          101       LYON  69008  4737.0          214.8     47  automobile
# 67            64       LYON  69004  4326.0          236.1     46  automobile
# 65            63       NICE   6300  4114.0          302.9     24  automobile
# 225          211   TOULOUSE  31400  3724.0          215.0     43  automobile
# 132          124       NICE   6000  3493.0          309.9     56  automobile
# 172          159      PARIS  75010  3238.0          315.8     55  automobile
# 141          133      PARIS  75011  3099.0          291.2     78  automobile
# 209          195       LYON  69006  2468.0          337.9     38  automobile
# ...

# %%
data.loc[data['type'] == 'automobile', ['identifiant', 'revenu']]
# Out:
#      identifiant  revenu
# 1              1  5310.0
# 65            63  4114.0
# 67            64  4326.0
# 87            83  2207.0
# 100           95  6069.0
# 106          101  4737.0
# 120          113  2314.0
# 132          124  3493.0
# 141          133  3099.0
# 154          144  2240.0
# 158          147  1288.0
# 159          148  1872.0
# 172          159  3238.0
# 209          195  2468.0
# 225          211  3724.0
# 240          224  5118.0

# %%
data.loc[(data['revenu'] >= 3000) & (data['type'] == 'automobile'), :].sort_values('revenu', ascending=False).head(15)
# Out:
#      identifiant     ville     CP  revenu  remboursement  duree        type  \
# 100           95     PARIS  75016  6069.0          341.4     24  automobile
# 1              1     PARIS  75009  5310.0          240.0     64  automobile
# 240          224     PARIS  75008  5118.0          238.2     25  automobile
# 106          101      LYON  69008  4737.0          214.8     47  automobile
# 67            64      LYON  69004  4326.0          236.1     46  automobile
# 65            63      NICE   6300  4114.0          302.9     24  automobile
# 225          211  TOULOUSE  31400  3724.0          215.0     43  automobile
# 132          124      NICE   6000  3493.0          309.9     56  automobile
# 172          159     PARIS  75010  3238.0          315.8     55  automobile
# 141          133     PARIS  75011  3099.0          291.2     78  automobile
#
#       taux
# 100  3.644
# 1    3.701
# 240  3.423
# 106  3.487
# 67   3.124
# 65   3.092
# 225  3.374
# 132  3.012
# 172  2.995
# ...

# %%
clients = pd.read_csv('prets.csv')

# %%
display(clients.loc[0:10, :])
display(clients.iloc[0:10, :])
# Out:
#     identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0             0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1             1      PARIS  75009  5310.0         240.00     64  automobile
# 2             1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3             2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4             3  MARSEILLE  13010  1684.0         586.03    180  immobilier
# 5             4  MARSEILLE  13012  1476.0         423.61    240  immobilier
# 6             5      PARIS  75016  2476.0         836.89    240  immobilier
# 7             6       LYON  69008  1867.0         711.33    240  immobilier
# 8             7       NICE   6000  5486.0        2956.95    300  immobilier
# 9             8   BORDEAUX  33200  3578.0         751.38    180  immobilier
# 10            9  MARSEILLE  13012  1386.0         612.61    180  immobilier
#
#      taux
# 0   1.168
# 1   3.701
# 2   1.173
# ...

# %%
# création d’un data frame trié pour ‘désordonner’ les Index

df_temp = clients.sort_values('revenu')

display(df_temp)
# Out:
#      identifiant      ville     CP  revenu  remboursement  duree        type  \
# 144          135  MARSEILLE  13013  1200.0         318.00    180  immobilier
# 61            60  MARSEILLE  13012  1201.0         688.17    240  immobilier
# 230          215  MARSEILLE  13006  1266.0         238.01    240  immobilier
# 157          147  MARSEILLE  13015  1288.0         199.64    240  immobilier
# 158          147  MARSEILLE  13015  1288.0         269.80     30  automobile
# ..           ...        ...    ...     ...            ...    ...         ...
# 206          193      PARIS  75003  6490.0        1765.28    240  immobilier
# 129          122      PARIS  75001  6536.0        2457.54    120  immobilier
# 83            80      PARIS  75019  6783.0        2197.69    180  immobilier
# 186          173      PARIS  75006  6784.0        3744.77    180  immobilier
# 137          129      PARIS  75012  6807.0        1899.15    180  immobilier
#
#       taux
# 144  1.314
# 61   1.113
# ...

# %%
# reset_index :

display(df_temp.reset_index())
# Out:
#      index  identifiant      ville     CP  revenu  remboursement  duree  \
# 0      144          135  MARSEILLE  13013  1200.0         318.00    180
# 1       61           60  MARSEILLE  13012  1201.0         688.17    240
# 2      230          215  MARSEILLE  13006  1266.0         238.01    240
# 3      157          147  MARSEILLE  13015  1288.0         199.64    240
# 4      158          147  MARSEILLE  13015  1288.0         269.80     30
# ..     ...          ...        ...    ...     ...            ...    ...
# 239    206          193      PARIS  75003  6490.0        1765.28    240
# 240    129          122      PARIS  75001  6536.0        2457.54    120
# 241     83           80      PARIS  75019  6783.0        2197.69    180
# 242    186          173      PARIS  75006  6784.0        3744.77    180
# 243    137          129      PARIS  75012  6807.0        1899.15    180
#
#            type   taux
# 0    immobilier  1.314
# 1    immobilier  1.113
# 2    immobilier  1.142
# ...

# %%
df_temp.iloc[144]
# Out:
# identifiant              11
# ville              BORDEAUX
# CP                    33200
# revenu               3346.0
# remboursement       1013.84
# duree                   240
# type             immobilier
# taux                  1.199
# Name: 12, dtype: object

# %%
display(df_temp.reset_index(drop=True))
df_temp.iloc[144]
# Out:
#      identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            135  MARSEILLE  13013  1200.0         318.00    180  immobilier
# 1             60  MARSEILLE  13012  1201.0         688.17    240  immobilier
# 2            215  MARSEILLE  13006  1266.0         238.01    240  immobilier
# 3            147  MARSEILLE  13015  1288.0         199.64    240  immobilier
# 4            147  MARSEILLE  13015  1288.0         269.80     30  automobile
# ..           ...        ...    ...     ...            ...    ...         ...
# 239          193      PARIS  75003  6490.0        1765.28    240  immobilier
# 240          122      PARIS  75001  6536.0        2457.54    120  immobilier
# 241           80      PARIS  75019  6783.0        2197.69    180  immobilier
# 242          173      PARIS  75006  6784.0        3744.77    180  immobilier
# 243          129      PARIS  75012  6807.0        1899.15    180  immobilier
#
#       taux
# 0    1.314
# 1    1.113
# ...

# %%
data.iloc[:3, -1:]
# Out:
#     taux
# 0  1.168
# 1  3.701
# 2  1.173

# %%
data.iloc[:3, -1:] = 1.05

# %%
display(data.iloc[:3, -1:])
# Out:
#    taux
# 0  1.05
# 1  1.05
# 2  1.05

# %%
data.loc[data['ville'] == 'PARIS', 'taux']=1.05
data.loc[data['ville'] == 'PARIS', :].head(20)
# Out:
#     identifiant  ville     CP  revenu  remboursement  duree        type  taux
# 1             1  PARIS  75009  5310.0         240.00     64  automobile  1.05
# 2             1  PARIS  75009  5310.0        1247.85    300  immobilier  1.05
# 6             5  PARIS  75016  2476.0         836.89    240  immobilier  1.05
# 11           10  PARIS  75011  2293.0         378.34    240  immobilier  1.05
# 16           15  PARIS  75003  4109.0        1220.37    240  immobilier  1.05
# 17           16  PARIS  75001  6118.0        1505.03    240  immobilier  1.05
# 18           17  PARIS  75011  4926.0        1507.36    240  immobilier  1.05
# 24           23  PARIS  75011  4469.0        1018.93    240  immobilier  1.05
# 26           25  PARIS  75009  5533.0        1394.32    300  immobilier  1.05
# 27           26  PARIS  75017  4265.0        1100.37    240  immobilier  1.05
# 28           27  PARIS  75001  1879.0         509.21    180  immobilier  1.05
# ...

# %%
mask = data['ville'] == 'MARSEILLE'
data.loc[mask, 'taux'] = data.loc[mask, 'taux'] + 0.05
data.head(10)
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
# 5            4  MARSEILLE  13012  1476.0         423.61    240  immobilier
# 6            5      PARIS  75016  2476.0         836.89    240  immobilier
# 7            6       LYON  69008  1867.0         711.33    240  immobilier
# 8            7       NICE   6000  5486.0        2956.95    300  immobilier
# 9            8   BORDEAUX  33200  3578.0         751.38    180  immobilier
#
#     taux
# 0  1.050
# 1  1.050
# 2  1.050
# 3  1.072
# 4  1.114
# 5  1.309
# 6  1.050
# 7  1.196
# 8  1.184
# 9  1.316
